# %%
# !pip install pandas_profiling
# Out:
# Collecting pandas_profiling
#   Downloading pandas_profiling-3.4.0-py2.py3-none-any.whl (315 kB)
# Requirement already satisfied: matplotlib<3.6,>=3.2 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (4.64.0)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (6.0)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.2-cp39-cp39-win_amd64.whl (2.1 MB)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (1.7.3)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9-py3-none-any.whl (10 kB)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (2.11.3)
# Collecting missingno<0.6,>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (1.21.5)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (0.13.2)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_profiling) (1.4.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\mahed\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\mahed\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (2.7.1)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting imagehash
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Requirement already satisfied: Pillow in c:\users\mahed\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas_profiling) (9.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas_profiling) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas_profiling) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas_profiling) (2021.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\mahed\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->pandas_profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->pandas_profiling) (4.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\mahed\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.6,>=3.2->pandas_profiling) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahed\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahed\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahed\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas_profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\mahed\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas_profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas_profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\mahed\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas_profiling) (1.3.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=ac54513921e447e2bf6d41c32fa36d208ad2321de487379403a2268d1397fef7
#   Stored in directory: c:\users\mahed\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: tangled-up-in-unicode, multimethod, visions, imagehash, pydantic, phik, missingno, htmlmin, pandas-profiling
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 missingno-0.5.1 multimethod-1.9 pandas-profiling-3.4.0 phik-0.12.2 pydantic-1.10.2 tangled-up-in-unicode-0.2.0 visions-0.7.5

# %%
import pandas_profiling 
from pandas_profiling import ProfileReport

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
# 17       16.29  3.71    Male     No  Sun  Dinner     3
# 18       16.97  3.50  Female     No  Sun  Dinner     3
# 19       20.65  3.35    Male     No  Sat  Dinner     3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
profile= ProfileReport(df, explorative=True, dark_mode=True)

# %%
profile.to_file('output.html')
# Out:
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install dtale
# Out:
# Collecting dtale
#   Using cached dtale-2.9.0-py2.py3-none-any.whl (12.8 MB)
# Collecting strsimpy
#   Using cached strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Collecting dash-colorscales
#   Using cached dash_colorscales-0.0.4-py3-none-any.whl
# Collecting dash>=2.0.0
#   Using cached dash-2.7.0-py3-none-any.whl (9.9 MB)
# Requirement already satisfied: seaborn in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: scipy in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.7.3)
# Collecting squarify
#   Using cached squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: Flask in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.1.2)
# Collecting missingno<=0.4.2
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (5.6.0)
# Requirement already satisfied: itsdangerous in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Collecting lz4
#   Using cached lz4-4.0.2-cp39-cp39-win_amd64.whl (98 kB)
# Requirement already satisfied: xlrd in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: numpy in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.21.5)
# Requirement already satisfied: openpyxl in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (3.0.9)
# Collecting kaleido
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Requirement already satisfied: matplotlib==3.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (3.6.0)
# Requirement already satisfied: cycler in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: scikit-learn in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.0.2)
# Requirement already satisfied: six in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: statsmodels in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: future>=0.14.0 in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (0.18.2)
# Collecting flask-ngrok
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Collecting dash-daq
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# Requirement already satisfied: requests in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (2.27.1)
# Collecting Flask-Compress
#   Using cached Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: certifi in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (2021.10.8)
# Requirement already satisfied: xarray in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (0.20.1)
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-1.2.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: networkx in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (2.7.1)
# Requirement already satisfied: pandas in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.4.2)
# Requirement already satisfied: et-xmlfile in c:\users\mahed\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib==3.6.0->dtale) (4.25.0)
# Collecting dash-html-components==2.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.4.0 requires matplotlib<3.6,>=3.2, but you have matplotlib 3.6.0 which is incompatible.
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\mahed\anaconda3\lib\site-packages (from Flask->dtale) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\mahed\anaconda3\lib\site-packages (from Flask->dtale) (2.0.3)
# Requirement already satisfied: click>=5.1 in c:\users\mahed\anaconda3\lib\site-packages (from Flask->dtale) (8.0.4)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from click>=5.1->Flask->dtale) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mahed\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->dtale) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Collecting brotli
#   Using cached Brotli-1.0.9-cp39-cp39-win_amd64.whl (383 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahed\anaconda3\lib\site-packages (from requests->dtale) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mahed\anaconda3\lib\site-packages (from requests->dtale) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mahed\anaconda3\lib\site-packages (from scikit-learn->dtale) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\mahed\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.2)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, dash, brotli, strsimpy, squarify, missingno, lz4, kaleido, flask-ngrok, Flask-Compress, dash-daq, dash-colorscales, dash-bootstrap-components, dtale
#   Attempting uninstall: missingno
#     Found existing installation: missingno 0.5.1
#     Uninstalling missingno-0.5.1:
#       Successfully uninstalled missingno-0.5.1
# Successfully installed Flask-Compress-1.13 brotli-1.0.9 dash-2.7.0 dash-bootstrap-components-1.2.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-2.9.0 flask-ngrok-0.0.25 kaleido-0.2.1 lz4-4.0.2 missingno-0.4.2 squarify-0.4.3 strsimpy-0.2.1

# %%
import dtale

# %%
dtale.show(df)
# Out:
# C:\Users\mahed\anaconda3\lib\site-packages\dtale\views.py:746: FutureWarning:
#
# ['sex', 'smoker', 'day', 'time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-JRM19PM:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df1= sns.load_dataset('titanic')

# %%
dtale.show(df1)
# Out:
# C:\Users\mahed\anaconda3\lib\site-packages\dtale\views.py:746: FutureWarning:
#
# ['embarked', 'class', 'deck', 'embark_town'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-JRM19PM:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# C:\Users\mahed\anaconda3\lib\site-packages\dtale\dash_application\charts.py:1610: FutureWarning:
#
# reindexing with a non-unique Index is deprecated and will raise in a future version.
#
# C:\Users\mahed\anaconda3\lib\site-packages\dtale\dash_application\charts.py:1610: FutureWarning:
#
# reindexing with a non-unique Index is deprecated and will raise in a future version.

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (4.64.0)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (3.6.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (1.4.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (1.21.5)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mahed\anaconda3\lib\site-packages (from sweetviz) (1.7.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\mahed\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.4)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.10.0 sweetviz-2.1.4

# %%
import sweetviz as vf

# %%
report=vf.analyze(df)
report.show_html('newreport')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report newreport was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# !pip install dataprep
# Out:
# Collecting dataprep
#   Using cached dataprep-0.4.5-py3-none-any.whl (9.9 MB)
# Collecting dask[array,dataframe,delayed]>=2022.3.0
#   Using cached dask-2022.10.2-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.8.1)
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp39-cp39-win_amd64.whl (1.2 MB)
# Collecting wordcloud<2.0,>=1.8
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.4.2)
# Collecting pydot<2.0.0,>=1.4.2
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting regex<2022.0.0,>=2021.8.3
#   Using cached regex-2021.11.10-cp39-cp39-win_amd64.whl (273 kB)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (4.64.0)
# Collecting flask<3,>=2
#   Using cached Flask-2.2.2-py3-none-any.whl (101 kB)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Using cached rapidfuzz-2.13.2-cp39-cp39-win_amd64.whl (1.0 MB)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2.4.2)
# Collecting scipy<2.0,>=1.8
#   Using cached scipy-1.9.3-cp39-cp39-win_amd64.whl (40.2 MB)
# Collecting metaphone<0.7,>=0.6
#   Using cached Metaphone-0.6-py3-none-any.whl
# Collecting python-crfsuite==0.9.8
#   Using cached python_crfsuite-0.9.8-cp39-cp39-win_amd64.whl (158 kB)
# Collecting varname<0.9.0,>=0.8.1
#   Using cached varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting jinja2<3.1,>=3.0
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (7.6.5)
# Collecting python-stdnum<2.0,>=1.16
#   Using cached python_stdnum-1.17-py2.py3-none-any.whl (943 kB)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Using cached Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting jsonpath-ng<2.0,>=1.5
#   Using cached jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.10.2)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.7)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.21.5)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.6.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\mahed\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp<4.0,>=3.6->dataprep) (4.1.1)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (9.0.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2022.2.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.2)
# Requirement already satisfied: click>=7.0 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (8.0.4)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from click>=7.0->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.4.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (4.11.3)
# Requirement already satisfied: Six in c:\users\mahed\anaconda3\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mahed\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.3.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.9.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.5)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: decorator in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: backcall in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Collecting ply
#   Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (302)
# Requirement already satisfied: fastjsonschema in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: joblib in c:\users\mahed\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mahed\anaconda3\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# Requirement already satisfied: locket in c:\users\mahed\anaconda3\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\mahed\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.8)
# Requirement already satisfied: prometheus-client in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\mahed\anaconda3\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.6.0)
# Requirement already satisfied: idna>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mahed\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: defusedxml in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.13)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: bleach in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: testpath in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mahed\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mahed\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Installing collected packages: jinja2, Werkzeug, regex, ply, flask, dask, wordcloud, varname, sqlalchemy, scipy, rapidfuzz, python-stdnum, python-crfsuite, pydot, metaphone, jsonpath-ng, flask-cors, dataprep
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.0.3
#     Uninstalling Werkzeug-2.0.3:
#       Successfully uninstalled Werkzeug-2.0.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.3.15
#     Uninstalling regex-2022.3.15:
#       Successfully uninstalled regex-2022.3.15
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.2
#     Uninstalling Flask-1.1.2:
#       Successfully uninstalled Flask-1.1.2
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.2.1
#     Uninstalling dask-2022.2.1:
#       Successfully uninstalled dask-2022.2.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.32
#     Uninstalling SQLAlchemy-1.4.32:
#       Successfully uninstalled SQLAlchemy-1.4.32
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\mahed\\anaconda3\\Lib\\site-packages\\~cipy\\cluster\\_hierarchy.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install dataprep
# Out:
# Requirement already satisfied: dataprep in c:\users\mahed\anaconda3\lib\site-packages (0.4.5)
# Requirement already satisfied: flask<3,>=2 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2.2.2)
# Requirement already satisfied: python-stdnum<2.0,>=1.16 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.17)
# Requirement already satisfied: varname<0.9.0,>=0.8.1 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (0.8.3)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.1.2 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2.13.2)
# Requirement already satisfied: pydot<2.0.0,>=1.4.2 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.4.2)
# Requirement already satisfied: numpy<2.0,>=1.21 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.21.5)
# Requirement already satisfied: bokeh<3,>=2 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.48 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (4.64.0)
# Requirement already satisfied: pandas<2.0,>=1.1 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.4.2)
# Requirement already satisfied: flask_cors<4.0.0,>=3.0.10 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.0.10)
# Requirement already satisfied: pydantic<2.0,>=1.6 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.10.2)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.8.2.2)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2021.11.10)
# Requirement already satisfied: python-crfsuite==0.9.8 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (0.9.8)
# Requirement already satisfied: jsonpath-ng<2.0,>=1.5 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.5.3)
# Requirement already satisfied: sqlalchemy==1.3.24 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.3.24)
# Requirement already satisfied: jinja2<3.1,>=3.0 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.0.3)
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (2022.10.2)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.8.1)
# Requirement already satisfied: metaphone<0.7,>=0.6 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (3.7)
# Requirement already satisfied: scipy<2.0,>=1.8 in c:\users\mahed\anaconda3\lib\site-packages (from dataprep) (1.9.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.6.3)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (5.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mahed\anaconda3\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\mahed\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp<4.0,>=3.6->dataprep) (4.1.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (9.0.1)
# Requirement already satisfied: tornado>=5.1 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (6.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\mahed\anaconda3\lib\site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: click>=7.0 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (8.0.4)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2022.2.0)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from click>=7.0->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.4.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\mahed\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from flask<3,>=2->dataprep) (4.11.3)
# Requirement already satisfied: Six in c:\users\mahed\anaconda3\lib\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mahed\anaconda3\lib\site-packages (from importlib-metadata>=3.6.0->flask<3,>=2->dataprep) (3.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.20)
# Requirement already satisfied: decorator in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (61.2.0)
# Requirement already satisfied: pickleshare in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: backcall in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: ply in c:\users\mahed\anaconda3\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: pyzmq>=13 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (302)
# Requirement already satisfied: fastjsonschema in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: joblib in c:\users\mahed\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mahed\anaconda3\lib\site-packages (from packaging>=16.8->bokeh<3,>=2->dataprep) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2021.3)
# Requirement already satisfied: locket in c:\users\mahed\anaconda3\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\mahed\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.5)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.4.4)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\mahed\anaconda3\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.6.0)
# Requirement already satisfied: idna>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.3)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mahed\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: bleach in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: testpath in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mahed\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mahed\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)

# %%
from dataprep.eda import create_report
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 from dataprep.eda import create_report
#
# File ~\anaconda3\lib\site-packages\dataprep\eda\__init__.py:8, in <module>
#       5 from bokeh.io import output_notebook
#       7 from ..utils import is_notebook
# ----> 8 from .correlation import compute_correlation, plot_correlation, render_correlation
#       9 from .create_report import create_report
#      10 from .create_db_report import create_db_report
#
# File ~\anaconda3\lib\site-packages\dataprep\eda\correlation\__init__.py:7, in <module>
#       1 """
#       2     This module implements the plot_correlation(df) function.
#       3 """
#       5 from typing import Any, Dict, List, Optional, Tuple, Union
# ----> 7 import dask.dataframe as dd
#       8 import pandas as pd
#      10 from ..configs import Config
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\__init__.py:4, in <module>
#       2 import dask.dataframe._pyarrow_compat
#       3 from dask.base import compute
# ----> 4 from dask.dataframe import backends, dispatch, rolling
#       5 from dask.dataframe.core import (
#       6     DataFrame,
#       7     Index,
#    (...)
#      13     to_timedelta,
#      14 )
#      15 from dask.dataframe.groupby import Aggregation
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\backends.py:21, in <module>
#      19 from dask.array.percentile import _percentile
#      20 from dask.backends import CreationDispatch, DaskBackendEntrypoint
# ---> 21 from dask.dataframe.core import DataFrame, Index, Scalar, Series, _Frame
#      22 from dask.dataframe.dispatch import (
#      23     categorical_dtype_dispatch,
#      24     concat,
#    (...)
#      36     union_categoricals_dispatch,
#      37 )
#      38 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\core.py:35, in <module>
#      33 from dask.blockwise import Blockwise, BlockwiseDep, BlockwiseDepDict, blockwise
#      34 from dask.context import globalmethod
# ---> 35 from dask.dataframe import methods
#      36 from dask.dataframe._compat import (
#      37     PANDAS_GT_140,
#      38     PANDAS_GT_150,
#      39     check_numeric_only_deprecation,
#      40 )
#      41 from dask.dataframe.accessor import CachedAccessor, DatetimeAccessor, StringAccessor
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\methods.py:22, in <module>
#      10 #  preserve compatibility while moving dispatch objects
#      11 from dask.dataframe.dispatch import (  # noqa: F401
#      12     concat,
#      13     concat_dispatch,
#    (...)
#      20     union_categoricals,
#      21 )
# ---> 22 from dask.dataframe.utils import is_dataframe_like, is_index_like, is_series_like
#      24 # cuDF may try to import old dispatch functions
#      25 hash_df = hash_object_dispatch
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\utils.py:19, in <module>
#      17 from dask.base import get_scheduler, is_dask_collection
#      18 from dask.core import get_deps
# ---> 19 from dask.dataframe import (  # noqa: F401 register pandas extension types
#      20     _dtypes,
#      21     methods,
#      22 )
#      23 from dask.dataframe._compat import PANDAS_GT_110, PANDAS_GT_120, tm  # noqa: F401
#      24 from dask.dataframe.dispatch import (  # noqa : F401
#      25     make_meta,
#      26     make_meta_obj,
#      27     meta_nonempty,
#      28 )
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\_dtypes.py:3, in <module>
#       1 import pandas as pd
# ----> 3 from dask.dataframe.extensions import make_array_nonempty, make_scalar
#       6 @make_array_nonempty.register(pd.DatetimeTZDtype)
#       7 def _(dtype):
#       8     return pd.array([pd.Timestamp(1), pd.NaT], dtype=dtype)
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\extensions.py:6, in <module>
#       1 """
#       2 Support for pandas ExtensionArray in dask.dataframe.
#       3
#       4 See :ref:`extensionarrays` for more.
#       5 """
# ----> 6 from dask.dataframe.accessor import (
#       7     register_dataframe_accessor,
#       8     register_index_accessor,
#       9     register_series_accessor,
#      10 )
#      11 from dask.utils import Dispatch
#      13 make_array_nonempty = Dispatch("make_array_nonempty")
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\accessor.py:190, in <module>
#     129     _accessor_methods = (
#     130         "asfreq",
#     131         "ceil",
#    (...)
#     145         "tz_localize",
#     146     )
#     148     _accessor_properties = (
#     149         "components",
#     150         "date",
#    (...)
#     186         "year",
#     187     )
# --> 190 class StringAccessor(Accessor):
#     191     """Accessor object for string properties of the Series values.
#     192
#     193     Examples
#    (...)
#     196     >>> s.str.lower()  # doctest: +SKIP
#     197     """
#     199     _accessor_name = "str"
#
# File ~\anaconda3\lib\site-packages\dask\dataframe\accessor.py:275, in StringAccessor()
#     272         meta = (self._series.name, object)
#     273     return self._function_map(method, pat=pat, n=n, expand=expand, meta=meta)
# --> 275 @derived_from(
#     276     pd.core.strings.StringMethods,
#     277     inconsistencies="``expand=True`` with unknown ``n`` will raise a ``NotImplementedError``",
#     278 )
#     279 def split(self, pat=None, n=-1, expand=False):
#     280     """Known inconsistencies: ``expand=True`` with unknown ``n`` will raise a ``NotImplementedError``."""
#     281     return self._split("split", pat=pat, n=n, expand=expand)
#
# TypeError: derived_from() got an unexpected keyword argument 'inconsistencies'

# %%
# !pip install lux
# Out:
# Collecting lux
#   Downloading lux-0.5.1.tar.gz (14 kB)
# Collecting lux-api
#   Downloading lux-api-0.5.1.tar.gz (127 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting lux-widget
#   Downloading lux-widget-0.1.11.tar.gz (2.5 MB)
# Requirement already satisfied: autopep8>=1.5 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (1.6.0)
# Collecting psutil>=5.9.0
#   Downloading psutil-5.9.4-cp36-abi3-win_amd64.whl (252 kB)
# Requirement already satisfied: pandas in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (3.6.0)
# Collecting iso3166
#   Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (1.21.5)
# Requirement already satisfied: altair>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (4.2.0)
# Requirement already satisfied: scipy>=1.3.3 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (1.9.3)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\mahed\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\mahed\\AppData\\Local\\Temp\\pip-install-ttxxshqe\\sh_6ba1879de0174c72a415302ff31ddc7e\\setup.py'"'"'; __file__='"'"'C:\\Users\\mahed\\AppData\\Local\\Temp\\pip-install-ttxxshqe\\sh_6ba1879de0174c72a415302ff31ddc7e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\mahed\AppData\Local\Temp\pip-pip-egg-info-z7f3zwje'
#          cwd: C:\Users\mahed\AppData\Local\Temp\pip-install-ttxxshqe\sh_6ba1879de0174c72a415302ff31ddc7e\
#     Complete output (7 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\mahed\AppData\Local\Temp\pip-install-ttxxshqe\sh_6ba1879de0174c72a415302ff31ddc7e\setup.py", line 5, in <module>
#         import sh
#       File "C:\Users\mahed\AppData\Local\Temp\pip-install-ttxxshqe\sh_6ba1879de0174c72a415302ff31ddc7e\sh.py", line 37, in <module>
#         import fcntl
#     ModuleNotFoundError: No module named 'fcntl'
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b7/09/89c28aaf2a49f226fef8587c90c6386bd2cc03a0295bc4ff7fc6ee43c01d/sh-1.14.3.tar.gz#sha256=e4045b6c732d9ce75d571c79f5ac2234edd9ae4f5fa9d59b09705082bdca18c7 (from https://pypi.org/simple/sh/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\mahed\\anaconda3\\Lib\\site-packages\\~sutil\\_psutil_windows.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\mahed\anaconda3\lib\site-packages (from lux-api->lux) (1.0.2)
# Collecting sh
#   Downloading sh-1.14.3.tar.gz (62 kB)
#   Downloading sh-1.14.2-py2.py3-none-any.whl (40 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\mahed\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api->lux) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\mahed\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api->lux) (3.0.3)
# Requirement already satisfied: entrypoints in c:\users\mahed\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api->lux) (0.4)
# Requirement already satisfied: toolz in c:\users\mahed\anaconda3\lib\site-packages (from altair>=4.0.0->lux-api->lux) (0.11.2)
# Collecting pycodestyle>=2.8.0
#   Downloading pycodestyle-2.9.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: toml in c:\users\mahed\anaconda3\lib\site-packages (from autopep8>=1.5->lux-api->lux) (0.10.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api->lux) (0.18.0)
# Requirement already satisfied: notebook>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from lux-widget->lux) (6.4.8)
# Requirement already satisfied: ipywidgets>=7.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from lux-widget->lux) (7.6.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (6.9.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (8.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.0->lux-widget->lux) (3.5.2)
# Requirement already satisfied: nest-asyncio in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (1.5.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.18.1)
# Requirement already satisfied: decorator in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (5.1.1)
# Requirement already satisfied: backcall in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (61.2.0)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.4.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (3.0.20)
# Requirement already satisfied: stack-data in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (302)
# Requirement already satisfied: cycler>=0.10 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mahed\anaconda3\lib\site-packages (from matplotlib>=3.0.0->lux-api->lux) (4.25.0)
# Requirement already satisfied: fastjsonschema in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->lux-widget->lux) (2.15.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (21.3.0)
# Requirement already satisfied: nbconvert in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.0.0->lux-widget->lux) (6.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas->lux-api->lux) (2021.3)
# Requirement already satisfied: wcwidth in c:\users\mahed\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\mahed\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget->lux) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\mahed\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api->lux) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from scikit-learn>=0.22->lux-api->lux) (2.2.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.0.0->lux-widget->lux) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget->lux) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mahed\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0.0->lux-widget->lux) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2->altair>=4.0.0->lux-api->lux) (2.1.1)
# Requirement already satisfied: defusedxml in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (1.5.0)
# Requirement already satisfied: testpath in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (4.11.1)
# Requirement already satisfied: bleach in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.0.0->lux-widget->lux) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mahed\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.0.0->lux-widget->lux) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mahed\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget->lux) (0.5.1)
# Requirement already satisfied: asttokens in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.2.2)
# Requirement already satisfied: executing in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget->lux) (0.8.3)
# Building wheels for collected packages: lux, lux-api, lux-widget
#   Building wheel for lux (setup.py): started
#   Building wheel for lux (setup.py): finished with status 'done'
#   Created wheel for lux: filename=lux-0.5.1-py3-none-any.whl size=11979 sha256=bc0323ea635fcd3b674658084295b9e8e640febd839e6261314310d1cff7dca8
#   Stored in directory: c:\users\mahed\appdata\local\pip\cache\wheels\eb\1a\ea\63737a35e77092f9238a1b023851b69f34270754063317527d
#   Building wheel for lux-api (PEP 517): started
#   Building wheel for lux-api (PEP 517): finished with status 'done'
#   Created wheel for lux-api: filename=lux_api-0.5.1-py3-none-any.whl size=185640 sha256=ea67a94940630b468edd3091d2c7d5c952a0eafd412cc8d90cf7c756722dc2e0
#   Stored in directory: c:\users\mahed\appdata\local\pip\cache\wheels\bd\05\a4\441d23d1cece85d6cd3cec43b38896e88a729e8048138825bd
#   Building wheel for lux-widget (setup.py): started
#   Building wheel for lux-widget (setup.py): finished with status 'done'
#   Created wheel for lux-widget: filename=lux_widget-0.1.11-py3-none-any.whl size=2540459 sha256=bffe0a3b607979859687a8ae8e99c92e63fa6c0ac9c78aafdb458ff5b0064520
#   Stored in directory: c:\users\mahed\appdata\local\pip\cache\wheels\03\dd\c3\286c3ca89a08533a99b0eb3f6e9a4b4c23476202c5a3fd622e
# Successfully built lux lux-api lux-widget
# Installing collected packages: pycodestyle, sh, psutil, lux-widget, iso3166, lux-api, lux
#   Attempting uninstall: pycodestyle
#     Found existing installation: pycodestyle 2.7.0
#     Uninstalling pycodestyle-2.7.0:
#       Successfully uninstalled pycodestyle-2.7.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0

# %%
# !pip install pandas_visual_analysis
# Out:
# Collecting pandas_visual_analysis
#   Downloading pandas_visual_analysis-0.0.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: setuptools>=49.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (61.2.0)
# Requirement already satisfied: plotly>=4.10.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (5.6.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (7.6.5)
# Requirement already satisfied: numpy>=1.19.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.21.5)
# Requirement already satisfied: blinker>=1.4 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.5)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from pandas_visual_analysis) (1.4.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (6.9.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (8.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->pandas_visual_analysis) (1.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: colorama in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.11.2)
# Requirement already satisfied: decorator in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.20)
# Requirement already satisfied: backcall in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahed\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mahed\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas_visual_analysis) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\mahed\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mahed\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mahed\anaconda3\lib\site-packages (from pandas>=1.1.0->pandas_visual_analysis) (2021.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mahed\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (8.0.1)
# Requirement already satisfied: six in c:\users\mahed\anaconda3\lib\site-packages (from plotly>=4.10.0->pandas_visual_analysis) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\mahed\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mahed\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mahed\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mahed\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\mahed\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mahed\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.4)
# Requirement already satisfied: bleach in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.13)
# Requirement already satisfied: testpath in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\mahed\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mahed\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\mahed\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.5.1)
# Requirement already satisfied: packaging in c:\users\mahed\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mahed\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas_visual_analysis) (3.0.4)
# Requirement already satisfied: pure-eval in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (2.0.5)
# Requirement already satisfied: executing in c:\users\mahed\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->pandas_visual_analysis) (0.8.3)
# Installing collected packages: pandas-visual-analysis
# Successfully installed pandas-visual-analysis-0.0.4

# %%
import lux
import seaborn as sns
dd= sns.load_dataset('titanic')
dd
# Out:
# Button(description='Toggle Pandas/Lux', layout=Layout(top='5px', width='140px'), style=ButtonStyle())
# Output()

# %%
from pandas_visual_analysis import VisualAnalysis
VisualAnalysis(dd)
# Out:
# VBox(children=(ToggleButtons(_dom_classes=('layout-70cedd26db7442f1a2277817e26795e2',), description='Selection…
